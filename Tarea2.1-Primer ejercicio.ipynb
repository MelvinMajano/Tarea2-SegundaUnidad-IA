# %%
import pandas as pd

df = pd.read_csv('./housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
datos =df.dropna()
datos.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
dumies = pd.get_dummies(datos['ocean_proximity'], dtype= int)
datos = pd.concat([datos, dumies], axis=1)

datos.drop('ocean_proximity', axis=1, inplace=True)
datos
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
datos.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
# <1H OCEAN            0.320831 -0.446928            0.045553    -0.003777
# INLAND              -0.055337  0.351084           -0.236968     0.026477
# ISLAND               0.009501 -0.016662            0.017105    -0.007603
# ...

# %%
import seaborn as sb

sb.set(rc={'figure.figsize':(15,8)})
sb.heatmap(data = datos.corr(), annot= True, cmap= 'YlGnBu')
# Out:
# <Axes: >

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   <1H OCEAN           20433 non-null  int64
#  10  INLAND              20433 non-null  int64
#  11  ISLAND              20433 non-null  int64
#  12  NEAR BAY            20433 non-null  int64
#  13  NEAR OCEAN          20433 non-null  int64
# dtypes: float64(9), int64(5)
# memory usage: 2.3 MB

# %%
datos.hist(bins=50, figsize=(20,15), edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>,
#         <Axes: title={'center': 'total_rooms'}>],
#        [<Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>],
#        [<Axes: title={'center': 'median_house_value'}>,
#         <Axes: title={'center': '<1H OCEAN'}>,
#         <Axes: title={'center': 'INLAND'}>,
#         <Axes: title={'center': 'ISLAND'}>],
#        [<Axes: title={'center': 'NEAR BAY'}>,
#         <Axes: title={'center': 'NEAR OCEAN'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
datos['room_ratio'] = datos['total_rooms'] / datos['total_bedrooms']
datos['PupulaHouse'] = datos['population']/datos['households']

# %%
EdadLimite =datos['housing_median_age']>50 #Verificamos que si hay datos que sean mayores a la censura que se nos dijo en el enunciado
EdadLimite
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: housing_median_age, Length: 20433, dtype: bool

# %%
PrecioLimite =datos['median_house_value']>500,000 #Verificamos que si hay datos que sean mayores a la censura que se nos dijo en el enunciado
EdadLimite
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: housing_median_age, Length: 20433, dtype: bool

# %%
IngresoLimite =datos['median_income']>15 #Verificamos que si hay datos que sean mayores a la censura que se nos dijo en el enunciado
IngresoLimite
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: median_income, Length: 20433, dtype: bool

# %%
edadLimiteDumie = pd.get_dummies(datos['housing_median_age']>50, dtype= int, drop_first=True) #Como si hay datos que estan censurados decidmos hacer dumies de ellos
edadLimiteDumie.columns = ['edadLimiteDumie']
edadLimiteDumie
# Out:
#        edadLimiteDumie
# 0                    0
# 1                    0
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 20635                0
# 20636                0
# 20637                0
# 20638                0
# 20639                0
#
# [20433 rows x 1 columns]

# %%
PrecioLimiteDumie = pd.get_dummies(datos['median_house_value']>50000, dtype= int, drop_first=True) #Como si hay datos que estan censurados decidmos hacer dumies de ellos
PrecioLimiteDumie.columns = ['PrecioLimiteDumie']
PrecioLimiteDumie
# Out:
#        PrecioLimiteDumie
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 20635                  1
# 20636                  1
# 20637                  1
# 20638                  1
# 20639                  1
#
# [20433 rows x 1 columns]

# %%
IngresoLimiteDumie = pd.get_dummies(datos['median_income']>15, dtype= int, drop_first=True) #Como si hay datos que estan censurados decidmos hacer dumies de ellos
IngresoLimiteDumie.columns = ['IngresoLimiteDumie']
IngresoLimiteDumie
# Out:
#        IngresoLimiteDumie
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 20635                   0
# 20636                   0
# 20637                   0
# 20638                   0
# 20639                   0
#
# [20433 rows x 1 columns]

# %%
datos = pd.concat([datos,edadLimiteDumie,PrecioLimiteDumie,IngresoLimiteDumie], axis=1)  #Agregamos los dumies alas caracterizticas de entrada

# %%
datos
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
X=datos.drop(['median_house_value','ISLAND'],axis=1)
y=datos['median_house_value']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.22)

model = LinearRegression()

model.fit(X_train,y_train)

predicciones = model.predict(X_test)

comparativa = {"predicciones":predicciones, "valor real": y_test}
result = pd.DataFrame(comparativa)
result
# Out:
#         predicciones  valor real
# 14872  194043.322249    128700.0
# 1449   214357.944427    144900.0
# 9668    14211.865634     97800.0
# 19569  139914.042713    102900.0
# 12951  134154.186227    112900.0
# ...              ...         ...
# 15674  327896.025095    500001.0
# 5663   220976.631258    243200.0
# 15498  358834.811871    237400.0
# 11770  141282.125647    186300.0
# 18025  267351.961885    234200.0
#
# [4496 rows x 2 columns]

# %%
model.score(X_test, y_test)
# Out:
# 0.6781799556387056

# %%
#Aunque no subio mucho, los dumies se crearon con el objetivo de tener una mejor precision que se pierde con la censura de los datos, ya que se tiene en cuenta si ese dato es mayor a su cesura

#Se realizo una relacion entre la population y houshold para tener una media mas exacta entre la gente que vive en la zona y las casas que hay
